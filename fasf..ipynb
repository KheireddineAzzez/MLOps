# %%
from tfx.components import CsvExampleGen 
from tfx.components import StatisticsGen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-74fc14990627> in <module>
# ----> 1 from tfx.components import CsvExampleGen
#       2 from tfx.components import StatisticsGen
#
# ~/miniconda3/envs/directml/lib/python3.6/site-packages/tfx/components/__init__.py in <module>
#      14 """Subpackage for TFX components."""
#      15 # For component user to direct use tfx.components.[...] as an alias.
# ---> 16 from tfx.components.bulk_inferrer.component import BulkInferrer
#      17 from tfx.components.common_nodes.importer_node import ImporterNode
#      18 from tfx.components.evaluator.component import Evaluator
#
# ~/miniconda3/envs/directml/lib/python3.6/site-packages/tfx/components/bulk_inferrer/component.py in <module>
#      16 from typing import Optional, Union
#      17
# ---> 18 from tfx import types
# ...
